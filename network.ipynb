# %% [markdown]
# **Параметры инициализации**

# %%
gap_time = 1
#gap_time = 10  # gap time between each segment
win_size = [10, 30, 60]  # window size of each segment
step_max = 5 # maximum step of ConvLSTM


#raw_data_path = "output_file.csv"
raw_data_path = "month_finally_transposed_hourly_resampled.csv"  # path to load raw data
#model_path = '../MSCRED/'
train_data_path = ""
test_data_path = ""
reconstructed_data_path = ""

'''
train_start_id = 10
train_end_id = 800

test_start_id = 800
test_end_id = 2000

valid_start_id = 800
valid_end_id = 1000
'''
train_start_id = 10
train_end_id = 200

test_start_id = 200
test_end_id = 672

valid_start_id = 200
valid_end_id = 400


training_iters = 5
save_model_step = 1

learning_rate = 0.0002

threhold = 0.005
alpha = 1.5

# %% [markdown]
# **Генерация сигнатурных матриц**

# %%
import numpy as np
import pandas as pd
#import os

# %%
class SignatureMatrices:
    def __init__(self):

        #df = pd.read_csv(raw_data_path)
        #df_new = df.drop(labels=0, axis=1)
        self.raw_data = pd.read_csv(raw_data_path, index_col = 0)
        self.series_number = self.raw_data.shape[0]
        self.series_length = self.raw_data.shape[1]
        self.signature_matrices_number = int(self.series_length / gap_time)

        print("series_number is", self.series_number)
        print("series_length is", self.series_length)
        print("signature_matrices_number is", self.signature_matrices_number)

    def signature_matrices_generation(self, win):
        """
        Generation signature matrices according win_size and gap_time, the size of raw_data is n * T, n is the number of
        time series, T is the length of time series.
        To represent the inter-correlations between different pairs of time series in a multivariate time series segment
        from t − w to t, we construct an n × n signature matrix Mt based upon the pairwise inner-product of two time series
        within this segment.
        :param win: the length of the time series segment
        :return: the signature matrices
        """

        if win == 0:
            print("The size of win cannot be 0")

        raw_data = np.asarray(self.raw_data)
        signature_matrices = np.zeros((self.signature_matrices_number, self.series_number, self.series_number))

        for t in range(win, self.signature_matrices_number):
            raw_data_t = raw_data[:, t - win:t]
            signature_matrices[t] = np.dot(raw_data_t, raw_data_t.T) / win
            
        return signature_matrices

    def generate_train_test(self, signature_matrices):
        """
        Generate train and test dataset, and store them to ../data/train/train.npy and ../data/test/test.npy
        :param signature_matrices:
        :return:
        """
        train_dataset = []
        test_dataset = []

        for data_id in range(self.signature_matrices_number):
            index = data_id - step_max + 1
            #print('Index:', index)
            if data_id < train_start_id:
                continue
            index_dataset = signature_matrices[:, index:index + step_max]
            if data_id < test_start_id:
                train_dataset.append(index_dataset)
            else:
                test_dataset.append(index_dataset)

        train_dataset = np.asarray(train_dataset)
        train_dataset = np.reshape(train_dataset, [-1, step_max, self.series_number, self.series_number,
                                                   signature_matrices.shape[0]])
        test_dataset = np.asarray(test_dataset)
        test_dataset = np.reshape(test_dataset, [-1, step_max,self.series_number, self.series_number,
                                                signature_matrices.shape[0]])

        print("train dataset shape is", train_dataset.shape)
        print("test dataset shape is", test_dataset.shape)

        train_path = ""
        #if not os.path.exists(train_path):
            #os.makedirs(train_path)
        train_path = "train.npy"

        test_path = ""
        #if not os.path.exists(test_path):
            #os.makedirs(test_path)
        test_path = "test.npy"

        np.save(train_path, train_dataset)
        np.save(test_path, test_dataset)
        print(train_dataset[-1].shape)

# %%
Matrices = SignatureMatrices()
signature_matrices = []

    # Generation signature matrices according the win size w
for w in win_size:
    signature_matrices.append(Matrices.signature_matrices_generation(w))
#print(signature_matrices)   

signature_matrices = np.asarray(signature_matrices)
print("the shape of signature_matrices is", signature_matrices.shape)

    # Generate train and test dataset
Matrices.generate_train_test(signature_matrices)
# Out:
# series_number is 4
# series_length is 672
# signature_matrices_number is 672
# the shape of signature_matrices is (3, 672, 4, 4)
# train dataset shape is (190, 5, 4, 4, 3)
# test dataset shape is (472, 5, 4, 4, 3)
# (5, 4, 4, 3)

# %%
#import utils as util
import numpy as np
import os
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# def cnn_encoder_layer(data, filter_layer, strides):
#     result = tf.nn.conv2d(
#         input=data,
#         filters=filter_layer,
#         strides=strides,
#         padding="SAME")
#     return tf.nn.selu(result)
#
#
# def tensor_variable(shape, name):
#     variable = tf.Variable(tf.zeros(shape), name=name)
#     variable = tf.compat.v1.get_variable(name, shape=shape, initializer=tf.compat.v1.keras.initializers.glorot_uniform())
#     return variable
#
#
# def cnn_encoder(data):
#     filter1 = tensor_variable([3, 3, 3, 32], "filter1")
#     strides1 = (1, 1, 1, 1)
#     cnn1_out = cnn_encoder_layer(data, filter1, strides1)
#
#     filter2 = tensor_variable([3, 3, 32, 64], "filter2")
#     strides2 = (1, 2, 2, 1)
#     cnn2_out = cnn_encoder_layer(cnn1_out, filter2, strides2)
#
#     filter3 = tensor_variable([2, 2, 64, 128], "filter3")
#     strides3 = (1, 2, 2, 1)
#     cnn3_out = cnn_encoder_layer(cnn2_out, filter3, strides3)
#
#     filter4 = tensor_variable([2, 2, 128, 256], "filter4")
#     strides4 = (1, 2, 2, 1)
#     cnn4_out = cnn_encoder_layer(cnn3_out, filter4, strides4)
#
#     return cnn1_out, cnn2_out, cnn3_out, cnn4_out
#
#
# def cnn_lstm_attention_layer(input_data, layer_number):
#     #outputs = tf.compat.v1.placeholder(tf.float32, [5, 30, 30, 32])
#     convlstm_layer = tf.compat.v1.keras.layers.ConvLSTM2D(
#         filters=input_data.shape[-1],
#         padding='same',
#         kernel_size=(2, 2),
#         use_bias=True,
#         return_sequences=True,
#         name="conv_lstm_cell" + str(layer_number))
#     #print('!', convlstm_layer )
#     outputs = convlstm_layer(input_data)
#     #outputs, state = tf.nn.dynamic_rnn(convlstm_layer, input_data, dtype=input_data.dtype)
#     #print('!', outputs)
#
#     #print('!', outputs)
#     attention_w = []
#     for k in range(step_max):
#         attention_w.append(tf.reduce_sum(tf.multiply(outputs[:, k], outputs[:, -1])) / step_max)
#     attention_w = tf.reshape(tf.nn.softmax(tf.stack(attention_w)), [1, step_max])
#     #print(input_data.shape[2])
#     outputs = tf.reshape(outputs, [step_max, -1])
#     #print('!', outputs)
#     # а вот это как раз та матрица, которая почему-то меньше нужного
#     outputs = tf.matmul(attention_w, outputs)
#     #ошибка в строке ниже
#     #print(outputs)
#     outputs = tf.reshape(outputs, [1, input_data.shape[2], input_data.shape[3], input_data.shape[4]])
#
#     return outputs, attention_w
#
#
# def cnn_decoder_layer(conv_lstm_out_c, filter, output_shape, strides):
#     deconv = tf.nn.conv2d_transpose(
#         value=conv_lstm_out_c,
#         filters=filter,
#         output_shape=output_shape,
#         strides=strides,
#         padding="SAME")
#     deconv = tf.nn.selu(deconv)
#     return deconv
#
#
# def cnn_decoder(lstm1_out, lstm2_out, lstm3_out, lstm4_out):
#     d_filter4 = tensor_variable([2, 2, 128, 256], "d_filter4")
#     dec4 = cnn_decoder_layer(lstm4_out, d_filter4, [1, 8, 8, 128], (1, 2, 2, 1))
#     dec4_concat = tf.concat([dec4, lstm3_out], axis=3)
#
#     d_filter3 = tensor_variable([2, 2, 64, 256], "d_filter3")
#     dec3 = cnn_decoder_layer(dec4_concat, d_filter3, [1, 15, 15, 64], (1, 2, 2, 1))
#     dec3_concat = tf.concat([dec3, lstm2_out], axis=3)
#
#     d_filter2 = tensor_variable([3, 3, 32, 128], "d_filter2")
#     dec2 = cnn_decoder_layer(dec3_concat, d_filter2, [1, 30, 30, 32], (1, 2, 2, 1))
#     dec2_concat = tf.concat([dec2, lstm1_out], axis=3)
#
#     d_filter1 = tensor_variable([3, 3, 3, 64], "d_filter1")
#     dec1 = cnn_decoder_layer(dec2_concat, d_filter1, [1, 30, 30, 3], (1, 1, 1, 1))
#
#     return dec1

# %% [markdown]
# matrix_data_path = train_data_path + "train.npy"
# matrix_gt_1 = np.load(matrix_data_path)
#
# data_input = tf.compat.v1.placeholder(tf.float32, [5, 30, 30, 3])
#
# conv1_out, conv2_out, conv3_out, conv4_out = cnn_encoder(data_input)
#
# conv1_out = tf.reshape(conv1_out, [ 1, 5, 30, 30, 32])
#     #print(conv1_out)
# conv2_out = tf.reshape(conv2_out, [ 1, 5, 15, 15, 64])
# conv3_out = tf.reshape(conv3_out, [ 1, 5, 8, 8, 128])
# conv4_out = tf.reshape(conv4_out, [ 1, 5, 4, 4, 256])
# conv1_lstm_attention_out, atten_weight_1 = cnn_lstm_attention_layer(conv1_out, 1)
#
#
#
#     #conv1_lstm_attention_out, atten_weight_1 = cnn_lstm_attention_layer(conv1_out, 1)
# conv2_lstm_attention_out, atten_weight_2 = cnn_lstm_attention_layer(conv2_out, 2)
#
#
#
# conv3_lstm_attention_out, atten_weight_3 = cnn_lstm_attention_layer(conv3_out, 3)
# conv4_lstm_attention_out, atten_weight_4 = cnn_lstm_attention_layer(conv4_out, 4)
#
# deconv_out = cnn_decoder(conv1_lstm_attention_out, conv2_lstm_attention_out, conv3_lstm_attention_out,
#                              conv4_lstm_attention_out)
# print(deconv_out)
#
# loss = tf.reduce_mean(tf.square(data_input[-1] - deconv_out))
#
# optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
#
# init = tf.global_variables_initializer()
# sess = tf.compat.v1.Session()
# sess.run(init)
#
# for idx in range(train_start_id, train_end_id):
#     matrix_gt = matrix_gt_1[idx - train_start_id]
#     feed_dict = {data_input: np.asarray(matrix_gt)}
#     a, loss_value = sess.run([optimizer, loss], feed_dict)
#     print("mse of last train data: " + str(loss_value))
#
# matrix_data_path = test_data_path + "test.npy"
# matrix_gt_1 = np.load(matrix_data_path)
# result_all = []
# for idx in range(test_start_id, test_end_id):
#     matrix_gt = matrix_gt_1[idx - test_start_id]
#     feed_dict = {data_input: np.asarray(matrix_gt)}
#     result, loss_value = sess.run([deconv_out, loss], feed_dict)
#     result_all.append(result)
#     print("mse of last test data: " + str(loss_value))
#
# reconstructed_path = reconstructed_data_path
# #if not os.path.exists(reconstructed_path):
#     #os.makedirs(reconstructed_path)
# reconstructed_path = reconstructed_path + "test_reconstructed.npy"
#
# result_all = np.asarray(result_all).reshape((-1, 30, 30, 3))
# print(result_all.shape)
# np.save(reconstructed_path, result_all)

# %%
def cnn_encoder_layer(data, filter_layer, strides):
    result = tf.nn.conv2d(
        input=data,
        filters=filter_layer,
        strides=strides,
        padding="SAME")
    return tf.nn.selu(result)


def tensor_variable(shape, name):
    with tf.compat.v1.variable_scope(tf.compat.v1.get_variable_scope(), reuse=tf.compat.v1.AUTO_REUSE):
        variable = tf.compat.v1.get_variable(name, shape=shape, initializer=tf.compat.v1.keras.initializers.glorot_uniform())
    return variable


def cnn_encoder(data):
    filter1 = tensor_variable([3, 3, 3, 32], "filter1")
    strides1 = (1, 1, 1, 1)
    cnn1_out = cnn_encoder_layer(data, filter1, strides1)
    # (5, 4, 4, 32)
    
    filter2 = tensor_variable([3, 3, 32, 64], "filter2")
    strides2 = (1, 2, 2, 1)
    cnn2_out = cnn_encoder_layer(cnn1_out, filter2, strides2)
    # (5, 2, 2, 64)
    
    return cnn1_out, cnn2_out#, cnn3_out, cnn4_out


def cnn_lstm_attention_layer(input_data, layer_number):
    #outputs = tf.compat.v1.placeholder(tf.float32, [5, 30, 30, 32])
    convlstm_layer = tf.compat.v1.keras.layers.ConvLSTM2D( 
        filters=input_data.shape[-1],
        padding='same',
        kernel_size=(2, 2),
        use_bias=True,
        return_sequences=True,
        name="conv_lstm_cell" + str(layer_number))
    #print('!', convlstm_layer )
    outputs = convlstm_layer(input_data)
    #outputs, state = tf.nn.dynamic_rnn(convlstm_layer, input_data, dtype=input_data.dtype)
    #print('!', outputs)

    #print('!', outputs)
    attention_w = []
    for k in range(step_max):
        attention_w.append(tf.reduce_sum(tf.multiply(outputs[:, k], outputs[:, -1])) / step_max)
    attention_w = tf.reshape(tf.nn.softmax(tf.stack(attention_w)), [1, step_max])
    #print(input_data.shape[2])
    outputs = tf.reshape(outputs, [step_max, -1])
    #print('!', outputs)
    # а вот это как раз та матрица, которая почему-то меньше нужного
    outputs = tf.matmul(attention_w, outputs)
    #ошибка в строке ниже
    #print(outputs)
    outputs = tf.reshape(outputs, [1, input_data.shape[2], input_data.shape[3], input_data.shape[4]])

    return outputs, attention_w


def cnn_decoder_layer(conv_lstm_out_c, filter, output_shape, strides):
    deconv = tf.nn.conv2d_transpose(
        value=conv_lstm_out_c,
        filters=filter,
        output_shape=output_shape,
        strides=strides,
        padding="SAME")
    deconv = tf.nn.selu(deconv)
    return deconv


def cnn_decoder(lstm1_out, lstm2_out):
    
    '''
    d_filter2 = tensor_variable([3, 3, 32, 128], "d_filter2")
    dec2 = cnn_decoder_layer(lstm2_out, d_filter2, [1, 4, 4, 32], (1, 2, 2, 1))
    dec2_concat = tf.concat([dec2, lstm1_out], axis=3)
    '''
    d_filter1 = tensor_variable([3, 3, 3, 64], "d_filter1")
    dec1 = cnn_decoder_layer(lstm2_out, d_filter1, [1, 4, 4, 3], (1, 2, 2, 1))
    
    '''
    d_filter4 = tensor_variable([2, 2, 128, 256], "d_filter4")
    dec4 = cnn_decoder_layer(lstm4_out, d_filter4, [1, 8, 8, 128], (1, 2, 2, 1))
    dec4_concat = tf.concat([dec4, lstm3_out], axis=3)

    d_filter3 = tensor_variable([2, 2, 64, 256], "d_filter3")
    dec3 = cnn_decoder_layer(dec4_concat, d_filter3, [1, 15, 15, 64], (1, 2, 2, 1))
    dec3_concat = tf.concat([dec3, lstm2_out], axis=3)
    
    d_filter2 = tensor_variable([3, 3, 32, 128], "d_filter2")
    dec2 = cnn_decoder_layer(dec3_concat, d_filter2, [1, 30, 30, 32], (1, 2, 2, 1))
    dec2_concat = tf.concat([dec2, lstm1_out], axis=3)

    d_filter1 = tensor_variable([3, 3, 3, 64], "d_filter1")
    dec1 = cnn_decoder_layer(dec2_concat, d_filter1, [1, 30, 30, 3], (1, 1, 1, 1))
    '''
    return dec1

# %%
matrix_data_path = train_data_path + "train.npy"
matrix_gt_1 = np.load(matrix_data_path)

data_input = tf.compat.v1.placeholder(tf.float32, [5, 4, 4, 3])

#conv1_out, conv2_out, conv3_out, conv4_out = cnn_encoder(data_input)
conv1_out, conv2_out = cnn_encoder(data_input)

#print(conv1_out.shape)
#print(conv2_out.shape)

conv1_out = tf.reshape(conv1_out, [ 1, 5, 4, 4, 32])
    
conv2_out = tf.reshape(conv2_out, [ 1, 5, 2, 2, 64])
#conv3_out = tf.reshape(conv3_out, [ 1, 5, 8, 8, 128])
#conv4_out = tf.reshape(conv4_out, [ 1, 5, 4, 4, 256])
conv1_lstm_attention_out, atten_weight_1 = cnn_lstm_attention_layer(conv1_out, 1)
 
#print('conv1_lstm_attention_out', conv1_lstm_attention_out)

#conv1_lstm_attention_out, atten_weight_1 = cnn_lstm_attention_layer(conv1_out, 1)
conv2_lstm_attention_out, atten_weight_2 = cnn_lstm_attention_layer(conv2_out, 2)

#print('conv2_lstm_attention_out', conv2_lstm_attention_out)

       
#conv3_lstm_attention_out, atten_weight_3 = cnn_lstm_attention_layer(conv3_out, 3)
#conv4_lstm_attention_out, atten_weight_4 = cnn_lstm_attention_layer(conv4_out, 4)
    
#deconv_out = cnn_decoder(conv1_lstm_attention_out, conv2_lstm_attention_out, conv3_lstm_attention_out,
                             #conv4_lstm_attention_out)

deconv_out = cnn_decoder(conv1_lstm_attention_out, conv2_lstm_attention_out)

#print(deconv_out.shape)

loss = tf.reduce_mean(tf.square(data_input[-1] - deconv_out))

optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
    
init = tf.global_variables_initializer()
sess = tf.compat.v1.Session()
sess.run(init)

loss_value_list = []
for idx in range(train_start_id, train_end_id):
    matrix_gt = matrix_gt_1[idx - train_start_id]
    feed_dict = {data_input: np.asarray(matrix_gt)}
    a, loss_value = sess.run([optimizer, loss], feed_dict)
    print("mse of last train data: " + str(loss_value))
    loss_value_list.append(loss_value)
   
matrix_data_path = "test.npy"
matrix_gt_1 = np.load(matrix_data_path)
result_all = []

for idx in range(test_start_id, test_end_id):
    matrix_gt = matrix_gt_1[idx - test_start_id]
    feed_dict = {data_input: np.asarray(matrix_gt)}
    result, loss_value = sess.run([deconv_out, loss], feed_dict)
    result_all.append(result)
    print("mse of last test data: " + str(loss_value))
    

reconstructed_path = reconstructed_data_path
#if not os.path.exists(reconstructed_path):
    #os.makedirs(reconstructed_path)
reconstructed_path = "test_reconstructed.npy"

result_all = np.asarray(result_all).reshape((-1, 4, 4, 3))
#print(result_all.shape)
np.save(reconstructed_path, result_all)
# Out:
# mse of last train data: 0.00019783915
# mse of last train data: 0.0002368724
# mse of last train data: 0.00027538903
# mse of last train data: 0.0003336545
# mse of last train data: 0.00026299575
# mse of last train data: 0.00013618784
# mse of last train data: 7.8969846e-05
# mse of last train data: 6.4959466e-05
# mse of last train data: 6.4361455e-05
# mse of last train data: 7.9777245e-05
# mse of last train data: 9.079332e-05
# mse of last train data: 8.647269e-05
# mse of last train data: 7.833566e-05
# mse of last train data: 6.7167195e-05
# mse of last train data: 5.95927e-05
# mse of last train data: 5.7799047e-05
# mse of last train data: 5.485074e-05
# mse of last train data: 5.503798e-05
# mse of last train data: 5.1276613e-05
# mse of last train data: 4.269766e-05
# mse of last train data: 5.9467555e-05
# mse of last train data: 5.92211e-05
# mse of last train data: 5.8105335e-05
# mse of last train data: 5.6693167e-05
# mse of last train data: 7.293823e-05
# mse of last train data: 5.7154433e-05
# mse of last train data: 4.5751014e-05
# mse of last train data: 4.200572e-05
# mse of last train data: 3.2887812e-05
# mse of last train data: 2.7404545e-05
# mse of last train data: 2.5483403e-05
# mse of last train data: 2.8607164e-05
# mse of last train data: 2.817419e-05
# mse of last train data: 2.3676175e-05
# mse of last train data: 2.2372487e-05
# mse of last train data: 1.8803052e-05
# mse of last train data: 1.4440305e-05
# mse of last train data: 1.2130859e-05
# mse of last train data: 1.0824449e-05
# mse of last train data: 1.1455745e-05
# mse of last train data: 1.2627698e-05
# mse of last train data: 1.04330065e-05
# mse of last train data: 8.6679765e-06
# mse of last train data: 6.536075e-06
# mse of last train data: 5.5258774e-06
# mse of last train data: 7.876292e-06
# mse of last train data: 1.5196216e-05
# mse of last train data: 1.234985e-05
# mse of last train data: 1.3990347e-05
# mse of last train data: 1.5501324e-05
# mse of last train data: 0.22297354
# mse of last train data: 0.43933216
# mse of last train data: 0.65344864
# mse of last train data: 0.639975
# mse of last train data: 0.627166
# mse of last train data: 0.6140799
# mse of last train data: 0.59881806
# mse of last train data: 0.5880344
# mse of last train data: 0.57267076
# mse of last train data: 0.55540586
# mse of last train data: 0.532144
# mse of last train data: 0.51470697
# mse of last train data: 0.49195352
# mse of last train data: 0.46346498
# mse of last train data: 0.42543054
# mse of last train data: 0.38886115
# mse of last train data: 0.35049403
# mse of last train data: 0.31332904
# mse of last train data: 0.27554592
# mse of last train data: 0.2395385
# mse of last train data: 0.20479786
# mse of last train data: 0.1760798
# mse of last train data: 0.15172435
# mse of last train data: 0.13508974
# mse of last train data: 0.11911303
# mse of last train data: 0.10566789
# mse of last train data: 0.09432433
# mse of last train data: 0.08470982
# mse of last train data: 0.07662735
# mse of last train data: 0.06931075
# mse of last train data: 0.06285425
# mse of last train data: 0.055041168
# mse of last train data: 0.047264572
# mse of last train data: 0.041818906
# mse of last train data: 0.037336513
# mse of last train data: 0.03282504
# mse of last train data: 0.029764444
# mse of last train data: 0.02732879
# mse of last train data: 0.025645902
# mse of last train data: 0.023556188
# mse of last train data: 0.021442153
# mse of last train data: 0.01938473
# mse of last train data: 0.017899355
# mse of last train data: 0.016856566
# mse of last train data: 0.01571462
# mse of last train data: 0.014397047
# mse of last train data: 0.013192595
# mse of last train data: 0.012078629
# mse of last train data: 0.011050906
# mse of last train data: 0.010049201
# mse of last train data: 0.008943191
# mse of last train data: 0.0078022406
# mse of last train data: 0.007109743
# mse of last train data: 0.0065525863
# mse of last train data: 0.006091201
# mse of last train data: 0.0056447615
# mse of last train data: 0.005092188
# mse of last train data: 0.0046229926
# mse of last train data: 0.004200297
# mse of last train data: 0.003809375
# mse of last train data: 0.0033494683
# mse of last train data: 0.0030015258
# mse of last train data: 0.0028020588
# mse of last train data: 0.0026286256
# mse of last train data: 0.002293398
# mse of last train data: 0.0019918054
# mse of last train data: 0.0018027932
# mse of last train data: 0.0017794553
# mse of last train data: 0.0018197108
# mse of last train data: 0.00200721
# mse of last train data: 0.0025188595
# mse of last train data: 0.002794315
# mse of last train data: 0.0027695813
# mse of last train data: 0.0026487317
# mse of last train data: 0.0024965357
# mse of last train data: 0.0025897443
# mse of last train data: 0.0027486673
# mse of last train data: 0.0031850247
# mse of last train data: 0.0036754033
# mse of last train data: 0.0042043794
# mse of last train data: 0.0043439707
# mse of last train data: 0.004238853
# mse of last train data: 0.0036018072
# mse of last train data: 0.0031314169
# mse of last train data: 0.0026515052
# mse of last train data: 0.002429641
# mse of last train data: 0.0022076264
# mse of last train data: 0.0020124186
# mse of last train data: 0.0018081389
# mse of last train data: 0.0016182037
# mse of last train data: 0.0015509204
# mse of last train data: 0.0015464063
# mse of last train data: 0.0013851676
# mse of last train data: 0.0016744215
# mse of last train data: 0.0018055355
# mse of last train data: 0.0024349946
# mse of last train data: 0.002562029
# mse of last train data: 0.0024520482
# mse of last train data: 0.002060129
# mse of last train data: 0.0015150504
# mse of last train data: 0.00113863
# mse of last train data: 0.0009865415
# mse of last train data: 0.0008848764
# mse of last train data: 0.00088087376
# mse of last train data: 0.0008430726
# mse of last train data: 0.0009247844
# mse of last train data: 0.0010004252
# mse of last train data: 0.0009266841
# mse of last train data: 0.0008362276
# mse of last train data: 0.00073635933
# mse of last train data: 0.00065612426
# mse of last train data: 0.0006242961
# mse of last train data: 0.0004691734
# mse of last train data: 0.00046049818
# mse of last train data: 0.00045842698
# mse of last train data: 0.00067863916
# mse of last train data: 0.0010871786
# mse of last train data: 0.0016437048
# mse of last train data: 0.0017391215
# mse of last train data: 0.0014917431
# mse of last train data: 0.0008783035
# mse of last train data: 0.0006128911
# mse of last train data: 0.00050423294
# mse of last train data: 0.00049284264
# mse of last train data: 0.00047210124
# mse of last train data: 0.00043992302
# mse of last train data: 0.00034439773
# mse of last train data: 0.00029269166
# mse of last train data: 0.00022862427
# mse of last train data: 0.00028396756
# mse of last train data: 0.00038874886
# mse of last train data: 0.0005003023
# mse of last train data: 0.0006304563
# mse of last train data: 0.00064367516
# mse of last train data: 0.0007701796
# mse of last train data: 0.0007796514
# mse of last train data: 0.0009410156
# mse of last train data: 0.0011589086
# mse of last train data: 0.0015807464
# mse of last train data: 0.002056366
# mse of last test data: 0.002548055
# mse of last test data: 0.0036811333
# mse of last test data: 0.004517741
# mse of last test data: 0.004541593
# mse of last test data: 0.0037354555
# mse of last test data: 0.0029012382
# mse of last test data: 0.002207015
# mse of last test data: 0.001718782
# mse of last test data: 0.0010459222
# mse of last test data: 0.00059962814
# mse of last test data: 0.00037029386
# mse of last test data: 0.0003306132
# mse of last test data: 0.00061243656
# mse of last test data: 0.0010735412
# mse of last test data: 0.0018998954
# mse of last test data: 0.0028341643
# mse of last test data: 0.0035320579
# mse of last test data: 0.004296416
# mse of last test data: 0.004243177
# mse of last test data: 0.004230958
# mse of last test data: 0.0037258368
# mse of last test data: 0.0041412287
# mse of last test data: 0.005084705
# mse of last test data: 0.0060621514
# mse of last test data: 0.006602716
# mse of last test data: 0.006580787
# mse of last test data: 0.0065751933
# mse of last test data: 0.006081971
# mse of last test data: 0.005565079
# mse of last test data: 0.0050199605
# mse of last test data: 0.0051763463
# mse of last test data: 0.0053069084
# mse of last test data: 0.0050209104
# mse of last test data: 0.0042617684
# mse of last test data: 0.003196245
# mse of last test data: 0.0025466545
# mse of last test data: 0.0022474218
# mse of last test data: 0.0022458697
# mse of last test data: 0.00251136
# mse of last test data: 0.002973701
# mse of last test data: 0.003764874
# mse of last test data: 0.0042609884
# mse of last test data: 0.0046103853
# mse of last test data: 0.004568566
# mse of last test data: 0.004524738
# mse of last test data: 0.0045027058
# mse of last test data: 0.0049071424
# mse of last test data: 0.0053413673
# mse of last test data: 0.005812784
# mse of last test data: 0.0063125193
# mse of last test data: 0.006824086
# mse of last test data: 0.0073750517
# mse of last test data: 0.0073646456
# mse of last test data: 0.007915969
# mse of last test data: 0.008500324
# mse of last test data: 0.00976693
# mse of last test data: 0.010423745
# mse of last test data: 0.011084366
# mse of last test data: 0.011059225
# mse of last test data: 0.011033845
# mse of last test data: 0.010372248
# mse of last test data: 0.009681411
# mse of last test data: 0.008968781
# mse of last test data: 0.008978344
# mse of last test data: 0.009631501
# mse of last test data: 0.010310203
# mse of last test data: 0.011742218
# mse of last test data: 0.013310482
# mse of last test data: 0.01579672
# mse of last test data: 0.018508391
# mse of last test data: 0.021432161
# mse of last test data: 0.023461884
# mse of last test data: 0.024505282
# mse of last test data: 0.024463274
# mse of last test data: 0.024434155
# mse of last test data: 0.023404561
# mse of last test data: 0.02233366
# mse of last test data: 0.02124068
# mse of last test data: 0.022279257
# mse of last test data: 0.023346467
# mse of last test data: 0.024406021
# mse of last test data: 0.024389485
# mse of last test data: 0.024375094
# mse of last test data: 0.025498455
# mse of last test data: 0.025544696
# mse of last test data: 0.024538973
# mse of last test data: 0.022323214
# mse of last test data: 0.021288661
# mse of last test data: 0.021338629
# mse of last test data: 0.021364802
# mse of last test data: 0.022412082
# mse of last test data: 0.02350798
# mse of last test data: 0.024617726
# mse of last test data: 0.02463986
# mse of last test data: 0.025782116
# mse of last test data: 0.026939968
# mse of last test data: 0.028099632
# mse of last test data: 0.028059086
# mse of last test data: 0.02800736
# mse of last test data: 0.029192453
# mse of last test data: 0.03040802
# mse of last test data: 0.030446567
# mse of last test data: 0.029209608
# mse of last test data: 0.027954103
# mse of last test data: 0.027959578
# mse of last test data: 0.027943537
# mse of last test data: 0.027918339
# mse of last test data: 0.029106893
# mse of last test data: 0.03035105
# mse of last test data: 0.030419601
# mse of last test data: 0.029207075
# mse of last test data: 0.027977325
# mse of last test data: 0.028008113
# mse of last test data: 0.026930874
# mse of last test data: 0.02576708
# mse of last test data: 0.024585977
# mse of last test data: 0.024598172
# mse of last test data: 0.024593502
# mse of last test data: 0.024572408
# mse of last test data: 0.024549043
# mse of last test data: 0.025660427
# mse of last test data: 0.026773209
# mse of last test data: 0.027884705
# mse of last test data: 0.02903275
# mse of last test data: 0.030215308
# mse of last test data: 0.032706786
# mse of last test data: 0.03398594
# mse of last test data: 0.034011815
# mse of last test data: 0.031537294
# mse of last test data: 0.027914435
# mse of last test data: 0.024565069
# mse of last test data: 0.02145295
# mse of last test data: 0.018589754
# mse of last test data: 0.015962334
# mse of last test data: 0.014280337
# mse of last test data: 0.0143138515
# mse of last test data: 0.015203
# mse of last test data: 0.016068844
# mse of last test data: 0.016023314
# mse of last test data: 0.015021629
# mse of last test data: 0.013309233
# mse of last test data: 0.010784243
# mse of last test data: 0.00869941
# mse of last test data: 0.0068282024
# mse of last test data: 0.006237894
# mse of last test data: 0.006190388
# mse of last test data: 0.006228143
# mse of last test data: 0.006196812
# mse of last test data: 0.006200839
# mse of last test data: 0.0062807403
# mse of last test data: 0.005759069
# mse of last test data: 0.0056904685
# mse of last test data: 0.006788815
# mse of last test data: 0.008596751
# mse of last test data: 0.009867207
# mse of last test data: 0.0105257435
# mse of last test data: 0.009822744
# mse of last test data: 0.009121562
# mse of last test data: 0.008387006
# mse of last test data: 0.0077791293
# mse of last test data: 0.0071725273
# mse of last test data: 0.006536516
# mse of last test data: 0.0065293275
# mse of last test data: 0.006017911
# mse of last test data: 0.0050563416
# mse of last test data: 0.0037168674
# mse of last test data: 0.0025856008
# mse of last test data: 0.0019489126
# mse of last test data: 0.001720509
# mse of last test data: 0.0018134849
# mse of last test data: 0.0018919259
# mse of last test data: 0.0018887069
# mse of last test data: 0.0016529178
# mse of last test data: 0.0016681763
# mse of last test data: 0.0016106874
# mse of last test data: 0.0016299068
# mse of last test data: 0.0012801926
# mse of last test data: 0.0008171313
# mse of last test data: 0.00058572454
# mse of last test data: 0.000573775
# mse of last test data: 0.0008068842
# mse of last test data: 0.0010188167
# mse of last test data: 0.0011257976
# mse of last test data: 0.0011163788
# mse of last test data: 0.0011159735
# mse of last test data: 0.0013532043
# mse of last test data: 0.0016131051
# mse of last test data: 0.0015803898
# mse of last test data: 0.0011677871
# mse of last test data: 0.00071539806
# mse of last test data: 0.00049945596
# mse of last test data: 0.00046325944
# mse of last test data: 0.0004641068
# mse of last test data: 0.0005146748
# mse of last test data: 0.00061778986
# mse of last test data: 0.000812958
# mse of last test data: 0.0009292844
# mse of last test data: 0.0009923197
# mse of last test data: 0.0011717761
# mse of last test data: 0.0012563838
# mse of last test data: 0.0012501634
# mse of last test data: 0.0010961253
# mse of last test data: 0.0010395292
# mse of last test data: 0.0009837617
# mse of last test data: 0.0012202909
# mse of last test data: 0.0015207091
# mse of last test data: 0.0017301651
# mse of last test data: 0.002017521
# mse of last test data: 0.0027311363
# mse of last test data: 0.0033779393
# mse of last test data: 0.0041939467
# mse of last test data: 0.004681407
# mse of last test data: 0.0050868317
# mse of last test data: 0.0050851204
# mse of last test data: 0.005627923
# mse of last test data: 0.0062170266
# mse of last test data: 0.0067223627
# mse of last test data: 0.0067305467
# mse of last test data: 0.007340556
# mse of last test data: 0.0073946994
# mse of last test data: 0.007948726
# mse of last test data: 0.008035226
# mse of last test data: 0.008611593
# mse of last test data: 0.008601393
# mse of last test data: 0.0080818795
# mse of last test data: 0.006921053
# mse of last test data: 0.005377474
# mse of last test data: 0.0043878364
# mse of last test data: 0.004064392
# mse of last test data: 0.0037232277
# mse of last test data: 0.0033493582
# mse of last test data: 0.002982912
# mse of last test data: 0.002648906
# mse of last test data: 0.0022912528
# mse of last test data: 0.0019994508
# mse of last test data: 0.0017417533
# mse of last test data: 0.0012843362
# mse of last test data: 0.00076039723
# mse of last test data: 0.0004628289
# mse of last test data: 0.00039136407
# mse of last test data: 0.00054929877
# mse of last test data: 0.00073834276
# mse of last test data: 0.00088457385
# mse of last test data: 0.0008803671
# mse of last test data: 0.00087514304
# mse of last test data: 0.001070215
# mse of last test data: 0.0010749564
# mse of last test data: 0.0011081775
# mse of last test data: 0.0008687661
# mse of last test data: 0.0008688555
# mse of last test data: 0.0010618231
# mse of last test data: 0.0015288453
# mse of last test data: 0.0017694939
# mse of last test data: 0.001606628
# mse of last test data: 0.001366696
# mse of last test data: 0.0016593724
# mse of last test data: 0.0025796148
# mse of last test data: 0.002834622
# mse of last test data: 0.002821409
# mse of last test data: 0.0023635055
# mse of last test data: 0.0023872952
# mse of last test data: 0.002439052
# mse of last test data: 0.002517634
# mse of last test data: 0.0029476304
# mse of last test data: 0.0037909904
# mse of last test data: 0.005185694
# mse of last test data: 0.0068009105
# mse of last test data: 0.008609942
# mse of last test data: 0.010615162
# mse of last test data: 0.012844541
# mse of last test data: 0.015306652
# mse of last test data: 0.017000925
# mse of last test data: 0.017876664
# mse of last test data: 0.017829245
# mse of last test data: 0.018786153
# mse of last test data: 0.019764094
# mse of last test data: 0.020774556
# mse of last test data: 0.019832088
# mse of last test data: 0.018896764
# mse of last test data: 0.01792125
# mse of last test data: 0.018954871
# mse of last test data: 0.021062307
# mse of last test data: 0.02209956
# mse of last test data: 0.02317862
# mse of last test data: 0.022089614
# mse of last test data: 0.021224113
# mse of last test data: 0.019242194
# mse of last test data: 0.018263774
# mse of last test data: 0.01839079
# mse of last test data: 0.017604297
# mse of last test data: 0.016084202
# mse of last test data: 0.0136793
# mse of last test data: 0.012193208
# mse of last test data: 0.011402577
# mse of last test data: 0.011415276
# mse of last test data: 0.010715968
# mse of last test data: 0.009409281
# mse of last test data: 0.008092539
# mse of last test data: 0.006901437
# mse of last test data: 0.005905278
# mse of last test data: 0.0045037717
# mse of last test data: 0.0036293238
# mse of last test data: 0.0032104754
# mse of last test data: 0.0032143828
# mse of last test data: 0.0032140624
# mse of last test data: 0.0032120522
# mse of last test data: 0.003599938
# mse of last test data: 0.0037434243
# mse of last test data: 0.0037067924
# mse of last test data: 0.003176627
# mse of last test data: 0.0028189763
# mse of last test data: 0.0027643132
# mse of last test data: 0.003037925
# mse of last test data: 0.0035538245
# mse of last test data: 0.0041025267
# mse of last test data: 0.004112229
# mse of last test data: 0.003586271
# mse of last test data: 0.0028138123
# mse of last test data: 0.0022856034
# mse of last test data: 0.0018968846
# mse of last test data: 0.0017222902
# mse of last test data: 0.001439463
# mse of last test data: 0.0013055163
# mse of last test data: 0.0010268725
# mse of last test data: 0.00081260316
# mse of last test data: 0.00054905546
# mse of last test data: 0.0004259936
# mse of last test data: 0.00042664618
# mse of last test data: 0.000428763
# mse of last test data: 0.00045869965
# mse of last test data: 0.0005108919
# mse of last test data: 0.0008454479
# mse of last test data: 0.0014231978
# mse of last test data: 0.0023038618
# mse of last test data: 0.0033180919
# mse of last test data: 0.0046310965
# mse of last test data: 0.0055565536
# mse of last test data: 0.0055339374
# mse of last test data: 0.0048739207
# mse of last test data: 0.0043692575
# mse of last test data: 0.0045475787
# mse of last test data: 0.004618328
# mse of last test data: 0.0043453206
# mse of last test data: 0.004074532
# mse of last test data: 0.003585982
# mse of last test data: 0.0030268077
# mse of last test data: 0.0025124557
# mse of last test data: 0.0026391698
# mse of last test data: 0.003116072
# mse of last test data: 0.0033274496
# mse of last test data: 0.003169018
# mse of last test data: 0.0028721702
# mse of last test data: 0.0023739366
# mse of last test data: 0.0024781362
# mse of last test data: 0.0033156655
# mse of last test data: 0.0042361747
# mse of last test data: 0.0047230828
# mse of last test data: 0.00483423
# mse of last test data: 0.004435602
# mse of last test data: 0.0038022783
# mse of last test data: 0.003045621
# mse of last test data: 0.0030418534
# mse of last test data: 0.0038253062
# mse of last test data: 0.0052395533
# mse of last test data: 0.0064792805
# mse of last test data: 0.00826043
# mse of last test data: 0.009515869
# mse of last test data: 0.009967668
# mse of last test data: 0.009516052
# mse of last test data: 0.009575018
# mse of last test data: 0.010753234
# mse of last test data: 0.01169987
# mse of last test data: 0.012657193
# mse of last test data: 0.013113123
# mse of last test data: 0.013850232
# mse of last test data: 0.014087222
# mse of last test data: 0.014329247
# mse of last test data: 0.014836636
# mse of last test data: 0.015122828
# mse of last test data: 0.014739078
# mse of last test data: 0.0139250895
# mse of last test data: 0.01266216
# mse of last test data: 0.011535392
# mse of last test data: 0.009966811
# mse of last test data: 0.008629982
# mse of last test data: 0.007897675
# mse of last test data: 0.008327008
# mse of last test data: 0.009845884
# mse of last test data: 0.011577305
# mse of last test data: 0.012933207
# mse of last test data: 0.013826485
# mse of last test data: 0.013269074
# mse of last test data: 0.011592395
# mse of last test data: 0.009278773
# mse of last test data: 0.007951948
# mse of last test data: 0.0069029904
# mse of last test data: 0.006570322
# mse of last test data: 0.0066093374
# mse of last test data: 0.0064554666
# mse of last test data: 0.0065817498
# mse of last test data: 0.006892782
# mse of last test data: 0.008702486
# mse of last test data: 0.010760804
# mse of last test data: 0.013164945
# mse of last test data: 0.015483905
# mse of last test data: 0.018293684
# mse of last test data: 0.020154228
# mse of last test data: 0.02152224
# mse of last test data: 0.021716207
# mse of last test data: 0.02086109
# mse of last test data: 0.018755566
# mse of last test data: 0.01671301
# mse of last test data: 0.016144564
# mse of last test data: 0.015385601
# mse of last test data: 0.013804746
# mse of last test data: 0.011897989
# mse of last test data: 0.011058085
# mse of last test data: 0.01150447
# mse of last test data: 0.013044463
# mse of last test data: 0.015330799
# mse of last test data: 0.017801067
# mse of last test data: 0.019481024
# mse of last test data: 0.020214839
# mse of last test data: 0.020046534
# mse of last test data: 0.019856289
# mse of last test data: 0.019536288
# mse of last test data: 0.020287605
# mse of last test data: 0.020189183
# mse of last test data: 0.019226165
# mse of last test data: 0.016631603
# mse of last test data: 0.014347687
# mse of last test data: 0.012362666
# mse of last test data: 0.011104636
# mse of last test data: 0.010674042
# mse of last test data: 0.010843233
# mse of last test data: 0.010210439
# mse of last test data: 0.008905851
# mse of last test data: 0.0074022845
# mse of last test data: 0.006322077
# mse of last test data: 0.0056634224
# mse of last test data: 0.00489376
# mse of last test data: 0.004507301
# mse of last test data: 0.0045492616
# mse of last test data: 0.005410351
# mse of last test data: 0.0067597963
# mse of last test data: 0.0077036885
# mse of last test data: 0.0074584284
# mse of last test data: 0.006216949
# mse of last test data: 0.0045233737
# mse of last test data: 0.0032619499
# mse of last test data: 0.0022141144
# mse of last test data: 0.0020752752
# mse of last test data: 0.0026470784
# mse of last test data: 0.0039294483
# mse of last test data: 0.004814317
# mse of last test data: 0.0049735773
# mse of last test data: 0.004238815
# mse of last test data: 0.0033213375
# mse of last test data: 0.002812134
# mse of last test data: 0.0024875412
# mse of last test data: 0.002262403
# mse of last test data: 0.0018658726
# mse of last test data: 0.0016612407
# mse of last test data: 0.0013781594
# mse of last test data: 0.0013181277
# mse of last test data: 0.0010227263
# mse of last test data: 0.0010260149
# mse of last test data: 0.00094879046
# mse of last test data: 0.0010351994
# mse of last test data: 0.000865085
# mse of last test data: 0.0007513124
# mse of last test data: 0.0006857167

# %%
import matplotlib
import matplotlib.pyplot as plt
idxs = list(range(1, len(loss_value_list) + 1))
plt.plot(idxs, loss_value_list)
plt.title('MSCRED: loss value during training ')
plt.show()

# %% [markdown]
# **Оценка данных на предмет аномалий**

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
#import utils as util
import re

# %%
# score initialization
valid_anomaly_score = np.zeros((valid_end_id - valid_start_id, 1))
test_anomaly_score = np.zeros((test_end_id - valid_end_id, 1))

# load the data from file
test_data_path = test_data_path
reconstructed_data_path = reconstructed_data_path
test_data_path = os.path.join(test_data_path, "test.npy")
reconstructed_data_path = os.path.join(reconstructed_data_path, "test_reconstructed.npy")
test_data = np.load("test.npy")
test_data = test_data[:, -1, ...]  # only compare the last matrix with the reconstructed data
reconstructed_data = np.load("test_reconstructed.npy")
print("The shape of test data is {}".format(test_data.shape))
print("The shape of reconstructed data is {}".format(reconstructed_data.shape))

valid_len = valid_end_id - valid_start_id

# compute the threshold, threshold = alpha * max{s(t)} , s(t) is the anomaly scores over validation period.
for i in range(valid_end_id - valid_start_id):
	error = np.square(np.subtract(test_data[i, ..., 0], reconstructed_data[i, ..., 0]))
	num_anom = len(np.where(error > threhold))
	valid_anomaly_score[i] = num_anom

max_valid_anom = np.max(valid_anomaly_score)
threshold = max_valid_anom * alpha

print("Max valid anom is %.2f" % max_valid_anom)
print("Threshold is %.2f" % threshold)

# compute the anomaly score in the test data.
for i in range(test_end_id - valid_end_id):
	error = np.square(np.subtract(test_data[i, ..., 0], reconstructed_data[i, ..., 0]))
	num_anom = len(np.where(error > threshold))
	test_anomaly_score[i - valid_len] = num_anom

# plot anomaly score curve and identification result
anomaly_pos = np.zeros(5)
root_cause_gt = np.zeros((5, 3))
anomaly_span = [10, 30, 90]

# Read the test_anomaly.csv, each line behalf of an anomaly, the first is the position, the next three number is the
# root cause.
root_cause_f = open("test_anomaly.csv", "r")

root_cause_gt = np.loadtxt(root_cause_f, delimiter=",", dtype=np.int32)
anomaly_pos = root_cause_gt[:, 0]
anomaly_pos = [(anomaly_pos[i]/gap_time-test_start_id-anomaly_span[i % 3]/gap_time) for i in range(5)]
for i in range(5):
	root_cause_gt[i][0] = anomaly_pos[i]


fig, axes = plt.subplots()
test_num = test_end_id - test_start_id
plt.xticks(fontsize = 10)
plt.ylim((0, 100))
plt.yticks(np.arange(0, 101, 20), fontsize = 10)
plt.plot(test_anomaly_score, 'b', linewidth = 2)
threshold = np.full((test_num), max_valid_anom * alpha)
axes.plot(threshold, color = 'red', linestyle = '--',linewidth = 2)
for k in range(len(anomaly_pos)):
	axes.axvspan(anomaly_pos[k], anomaly_pos[k] + anomaly_span[k%3]/gap_time, color='red', linewidth=2)

#labels = [' ', '100', '200', '300', '400']#axes.set_xticklabels(labels, rotation = 25, fontsize = 20)
plt.xlabel('Test Time', fontsize = 25)
plt.ylabel('Anomaly Score', fontsize = 25)
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
axes.yaxis.set_ticks_position('left')
axes.xaxis.set_ticks_position('bottom')
fig.subplots_adjust(bottom=0.25)
fig.subplots_adjust(left=0.25)
plt.title("MSCRED", size = 25)
plt.show()
# Out:
# The shape of test data is (472, 4, 4, 3)
# The shape of reconstructed data is (472, 4, 4, 3)
# Max valid anom is 2.00
# Threshold is 3.00
